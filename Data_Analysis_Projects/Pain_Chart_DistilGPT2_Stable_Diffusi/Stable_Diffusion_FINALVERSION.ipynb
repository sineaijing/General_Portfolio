# %% [markdown]
# # Demo for stable-diffusion-pytorch

# %% [markdown]
# ## Install (takes about 1~5 minutes)

# %%
# %cd /content
# !git clone https://github.com/kjsman/stable-diffusion-pytorch
# Out:
# /content
# Cloning into 'stable-diffusion-pytorch'...
# remote: Enumerating objects: 87, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 87 (delta 49), reused 50 (delta 23), pack-reused 0
# Unpacking objects: 100% (87/87), 26.52 KiB | 936.00 KiB/s, done.

# %%
# Note that all depencdencies of stable-diffusion-pytorch is pre-installed
# on Colab environment. This cell basically does nothing on Colab.
# %cd /content/stable-diffusion-pytorch
# %pip install -r requirements.txt
# Out:
# /content/stable-diffusion-pytorch
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 1)) (1.13.1+cu116)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 2)) (1.22.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 3)) (8.4.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 4)) (2022.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 5)) (4.65.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.9->-r requirements.txt (line 1)) (4.5.0)

# %%
# %cd /content/stable-diffusion-pytorch
# !wget https://huggingface.co/jinseokim/stable-diffusion-pytorch-data/resolve/main/data.v20221029.tar
# !tar -xf data.v20221029.tar
# Out:
# /content/stable-diffusion-pytorch
# --2023-03-14 16:34:52--  https://huggingface.co/jinseokim/stable-diffusion-pytorch-data/resolve/main/data.v20221029.tar
# Resolving huggingface.co (huggingface.co)... 3.216.0.246, 54.82.45.103, 34.202.121.154, ...
# Connecting to huggingface.co (huggingface.co)|3.216.0.246|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/3d/4b/3d4ba72796d9403407c086755997d25023b743581f1dfb562b61d3c6a3bd773f/9708a9fa7fb0805bd1a58896e5adf9666237361e57c2578e8a76e216568b9d77?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27data.v20221029.tar%3B+filename%3D%22data.v20221029.tar%22%3B&response-content-type=application%2Fx-tar&Expires=1679070894&Policy=...__&Signature=wfdlS8Npvt2aZ%7EFH7dZjHNmjCNTatiF70qmFDoROm8IwzDyGT38Ldtuz5iTdduDMEvZvWB1oBh5tiyCDmRthrKBMMcGJurVpZV8KjZULuMo6vrqvW1thxNdGZiwbdP8PzDZw0gqcRR6MQdZ2B6A3qftFoAORa1q7ZCFI4b7BdSQ6pPE6RyLAVEFWqyEkn7M8AQ5cK7pIKf9hx3HluhbP3wy3KCrJ%7EvTPjhjtBw7828IlmSovA0MR8R2Hz0GvvRLYgALaRzsMOY6AS7oXasTYd1jeDnYgrUzW8TZFW1Q1fgaC2quTqvn6DltuWCdcY1RdPUn5MSPVCu%7EusTdX2ELSiA__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2023-03-14 16:34:53--  https://cdn-lfs.huggingface.co/repos/3d/4b/3d4ba72796d9403407c086755997d25023b743581f1dfb562b61d3c6a3bd773f/9708a9fa7fb0805bd1a58896e5adf9666237361e57c2578e8a76e216568b9d77?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27data.v20221029.tar%3B+filename%3D%22data.v20221029.tar%22%3B&response-content-type=application%2Fx-tar&Expires=1679070894&Policy=...__&Signature=wfdlS8Npvt2aZ%7EFH7dZjHNmjCNTatiF70qmFDoROm8IwzDyGT38Ldtuz5iTdduDMEvZvWB1oBh5tiyCDmRthrKBMMcGJurVpZV8KjZULuMo6vrqvW1thxNdGZiwbdP8PzDZw0gqcRR6MQdZ2B6A3qftFoAORa1q7ZCFI4b7BdSQ6pPE6RyLAVEFWqyEkn7M8AQ5cK7pIKf9hx3HluhbP3wy3KCrJ%7EvTPjhjtBw7828IlmSovA0MR8R2Hz0GvvRLYgALaRzsMOY6AS7oXasTYd1jeDnYgrUzW8TZFW1Q1fgaC2quTqvn6DltuWCdcY1RdPUn5MSPVCu%7EusTdX2ELSiA__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 13.227.254.123, 13.227.254.52, 13.227.254.47, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|13.227.254.123|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4266787840 (4.0G) [application/x-tar]
# Saving to: ‘data.v20221029.tar’
#
# data.v20221029.tar  100%[===================>]   3.97G  96.9MB/s    in 31s
#
# 2023-03-14 16:35:25 (130 MB/s) - ‘data.v20221029.tar’ saved [4266787840/4266787840]

# %%
! pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 97.4 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.25.1)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.2-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 22.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 105.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (4.0.0)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.2 tokenizers-0.13.2 transformers-4.26.1

# %% [markdown]
# ## Run

# %%
#@title Preload models (takes about ~20 seconds on default settings)

from stable_diffusion_pytorch import model_loader
models = model_loader.preload_models('cpu')

# %% [markdown]
# ## Generate prompts for the stable diffusion
# I am generating prompts for the stable diffusion model - here without finetuning on my own dataset.

# %%
#@title Inference (takes about 30~40 seconds on default settings)

from stable_diffusion_pytorch import pipeline

#for i in data:
prompt = 'Chronic pain people are ills because it has been long since you heard your name. ' #@param { type: "string" }
prompts = [prompt]

uncond_prompt = "text, letters"  #@param { type: "string" }
uncond_prompts = [uncond_prompt] if uncond_prompt else None

upload_input_image = False  #@param { type: "boolean" }
input_images = None
if upload_input_image:
    from PIL import Image
    from google.colab import files
    print("Upload an input image:")
    path = list(files.upload().keys())[0]
    input_images = [Image.open(path)]

strength = 0.8  #@param { type:"slider", min: 0, max: 1, step: 0.01 }

do_cfg = True  #@param { type: "boolean" }
cfg_scale = 7.5  #@param { type:"slider", min: 1, max: 14, step: 0.5 }
height = 512  #@param { type: "integer" }
width = 512  #@param { type: "integer" }
sampler = "k_lms"  #@param ["k_lms", "k_euler", "k_euler_ancestral"]
n_inference_steps = 50  #@param { type: "integer" }

use_seed = False  #@param { type: "boolean" }
if use_seed:
    seed = 42  #@param { type: "integer" }
else:
    seed = None

pipeline.generate(prompts=prompts, uncond_prompts=uncond_prompts,
                  input_images=input_images, strength=strength,
                  do_cfg=do_cfg, cfg_scale=cfg_scale,
                  height=height, width=width, sampler=sampler,
                  n_inference_steps=n_inference_steps, seed=seed,
                  models=models, device='cuda', idle_device='cpu')[0]
# Out:
# 100%|██████████| 50/50 [00:27<00:00,  1.82it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F8994D74580>
